# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
Denmark = gpd.read_file("KOM_MULTIPART.shp")

# %%
fig, ax = plt.subplots(figsize = (20,10))
Denmark.plot(ax = ax, color = "#01153e", edgecolor = "black")
plt.show()

# %%
# from: https://www.energidataservice.dk/dataset/communityproduction/resource_extract/1ed52ea0-6f73-4067-a89e-43dd41fee45b?page=1&applied-filters=Month%7C%3D%7C2018-09-01+00%3A00#resource-preview
power = pd.read_excel("Production_per_Municipality_Data-23ea948e940b4fe28ded776473088717.xlsx", dtype = {"MunicipalityNo": str})
power["KOMKODE"] = str(0)+power["MunicipalityNo"]
merge = Denmark.merge(power, how = "left", on = "KOMKODE")

# %%
merge.head()
# Out:
#   REGIONKODE          REGIONNAVN KOMKODE   KOMNAVN      Landsel  Landskode  \
# 0       1084  Region Hovedstaden    0400  Bornholm     Bornholm          8
# 1       1085     Region Sjælland    0259      Køge  Østsjælland          7
# 2       1085     Region Sjælland    0350     Lejre  Østsjælland          7
# 3       1085     Region Sjælland    0265  Roskilde  Østsjælland          7
# 4       1085     Region Sjælland    0269    Solrød  Østsjælland          7
#
#                                             geometry      Month  \
# 0  (POLYGON ((891187.49 6118170.25, 891186.3 6118... 2018-09-01
# 1  (POLYGON ((702347.24 6155011.31, 702342.570000... 2018-09-01
# 2  (POLYGON ((684542.65 6171881.69, 684546.91 617... 2018-09-01
# 3  (POLYGON ((694011.6900000001 6183259.77, 69402... 2018-09-01
# 4  (POLYGON ((703151.55 6157196.08, 703152.15 615... 2018-09-01
#
#   MunicipalityNo  OnshoreWindPower  OffshoreWindPower  SolarPower  \
# ...

# %%
fig, ax = plt.subplots(figsize = (20,10))
merge.plot(ax = ax, edgecolor = "black", column = "OnshoreWindPower")
plt.show()
# Out:
# C:\Users\morte\Anaconda3\lib\site-packages\numpy\core\_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# C:\Users\morte\Anaconda3\lib\site-packages\numpy\core\_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# C:\Users\morte\Anaconda3\lib\site-packages\matplotlib\colors.py:512: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
merge.plot(column = "OnshoreWindPower", cmap = "RdYlGn")
